# %%
import openmc.statepoint

# %%
sp=openmc.statepoint.StatePoint('statepoint.20.h5')

# %%
sp.source
# Out:
# array([ (1.0, [-1.2013583943061432, -9.142369548372468, 2.065306754313196], [0.08285479073961466, 0.028069583443121597, -0.9961662422190506], 2.601824815381762),
#        (1.0, [-1.2013583943061432, -9.142369548372468, 2.065306754313196], [-0.385738311793299, 0.9096829643720343, 0.15389236220866775], 3.573670733158392),
#        (1.0, [-2.504492457054022, 3.52552830317117, -3.986382030357201], [-0.16099022043449673, 0.9828693129711839, 0.08972214076806863], 0.14819888838088136),
#        (1.0, [-2.504492457054022, 3.52552830317117, -3.986382030357201], [-0.6521647557935819, 0.17000769704381294, -0.738768241227624], 0.25812978196010905),
#        (1.0, [-2.2343874617128145, 8.930660005996035, -5.996444095420648], [-0.490269831728943, -0.8669336101272082, 0.08978645626306753], 1.5679323639891094),
#        (1.0, [-2.2343874617128145, 8.930660005996035, -5.996444095420648], [-0.4146518016880637, 0.8507299751324562, 0.3229897719247052], 1.6742432543343362),
# ...

# %%
a=sp.source

# %%
data=[e[1][0] for e in a]

# %%
a.shape
# Out:
# (1000L,)

# %%
data
# Out:
# [-1.2013583943061432,
#  -1.2013583943061432,
#  -2.5044924570540221,
#  -2.5044924570540221,
#  -2.2343874617128145,
#  -2.2343874617128145,
#  -0.24663985864419957,
#  -0.24663985864419957,
#  10.380319799423564,
#  10.380319799423564,
#  7.485984784991583,
#  7.485984784991583,
#  0.32674917319729468,
#  0.32674917319729468,
#  10.280022389167716,
#  -3.682462884174857,
#  -3.682462884174857,
#  2.1915373329132164,
#  2.1915373329132164,
#  -8.7176650469346768,
#  -8.7176650469346768,
#  8.6536165034369859,
#  8.6536165034369859,
#  7.7262806419683452,
#  7.7262806419683452,
#  -5.1928664465714283,
#  -5.1928664465714283,
#  -1.211265301464582,
#  -7.3623391443559703,
#  -8.8964085422033694,
#  1.3371229485071168,
#  1.3371229485071168,
#  4.0777601478290437,
#  4.0777601478290437,
#  10.041380527566625,
#  -7.2338140059550149,
#  -7.2338140059550149,
#  6.4720597639640776,
#  6.4720597639640776,
#  -8.848142899586497,
#  -8.848142899586497,
#  1.4830459336202513,
# ...

# %%
import ulsif
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-599cfb65233d> in <module>()
# ----> 1 import ulsif
#
# ImportError: No module named ulsif
